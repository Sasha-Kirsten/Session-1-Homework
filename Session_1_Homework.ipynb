# %% [markdown]
# <a href="https://colab.research.google.com/github/Sasha-Kirsten/Session-1-Homework/blob/main/Session_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.21.6'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Out:
# --2022-09-05 19:57:38--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]   1.41M  --.-KB/s    in 0.04s
#
# 2022-09-05 19:57:38 (39.9 MB/s) - ‘data.csv’ saved [1475504/1475504]

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# 11914 rows

# %%
newData = df.groupby('Make').count().sort_values('Popularity',ascending=False)
newData
# Out:
#                Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make
# Chevrolet       1123  1123              1123       1117              1121
# Ford             881   881               881        868               881
# Volkswagen       809   809               809        809               805
# Toyota           746   746               746        744               745
# Dodge            626   626               626        626               626
# Nissan           558   558               558        548               558
# GMC              515   515               515        515               515
# Honda            449   449               449        447               449
# Mazda            423   423               423        423               403
# Cadillac         397   397               397        397               397
# Mercedes-Benz    353   353               353        352               353
# Suzuki           351   351               348        351               351
# ...

# %%
# Chevrolet, Ford, Volkswagen

# %%
newData2 = df[df.Make == 'Audi']['Model'].unique()
 
newData2
# Out:
# array(['100', '200', '80', '90', 'A3', 'A4 allroad', 'A4', 'A5', 'A6',
#        'A7', 'A8', 'allroad quattro', 'allroad', 'Cabriolet', 'Coupe',
#        'Q3', 'Q5', 'Q7', 'R8', 'RS 4', 'RS 5', 'RS 6', 'RS 7', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S8', 'SQ5', 'TT RS', 'TT', 'TTS', 'V8'],
#       dtype=object)

# %%
# The value is 34, we could it ourselves

# %%
missingData = df.isnull().sum()
missingData
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# 5 columns have missing values

# %%
medValuesEngine = df['Engine Cylinders'].median()
medValuesEngine
# Out:
# 6.0

# %%
frquenctValueEngine = df['Engine Cylinders'].value_counts()
frquenctValueEngine
# Out:
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: Engine Cylinders, dtype: int64

# %%
# The frequenct value of the "Engine Cylinders" is 4.0

# %%
NewMedian = df['Engine Cylinders'].fillna(frquenctValueEngine).median()
NewMedian
# Out:
# 6.0

# %%
# Has it changed (Mode and Median): Yes!

# %%
newData3 = df[df.Make == 'Lotus'][['Engine HP','Engine Cylinders']].drop_duplicates()
newData3
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
X = newData3.values
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
X.T
# Out:
# array([[189., 218., 217., 350., 400., 276., 345., 257., 240.],
#        [  4.,   4.,   4.,   8.,   6.,   6.,   6.,   4.,   4.]])

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
w = XTX_inv.dot(X.T).dot(y)
w
# Out:
# array([  4.59494481, -63.56432501])
